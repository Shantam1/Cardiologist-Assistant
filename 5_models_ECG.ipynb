# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
import numpy as np

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from skimage import color
from skimage.transform import resize
from skimage.filters import threshold_otsu, gaussian
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

# %%
model_save_dir = r"saved_models"

try:
    os.mkdir(model_save_dir)
except:
    pass

# %%
# Set the path to your dataset
dataset_path = r"ECG_IMAGES_DATASET"

num_classes = len(os.listdir(dataset_path))
# Define image size and other parameters

# Example parameters
input_shape = (512, 512, 3)
num_classes = 4
batch_size = 32

# Create an ImageDataGenerator for data augmentation and normalization
datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2  # Split the data into training and validation sets
)

# Generate training dataset
train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(input_shape[0], input_shape[1]),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

# Generate validation dataset
validation_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(input_shape[0], input_shape[1]),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

def plot_hist(model):
    history = model.history
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
# Out:
# Found 745 images belonging to 4 classes.
# Found 183 images belonging to 4 classes.

# %% [markdown]
# ## LeNet 5

# %%
# Define LeNet-5 model
lenet = models.Sequential()
lenet.add(layers.Conv2D(6, (5, 5), activation='relu', input_shape=input_shape))
lenet.add(layers.MaxPooling2D((2, 2)))
lenet.add(layers.Conv2D(16, (5, 5), activation='relu'))
lenet.add(layers.MaxPooling2D((2, 2)))
lenet.add(layers.Flatten())
lenet.add(layers.Dense(120, activation='relu'))
lenet.add(layers.Dense(84, activation='relu'))
lenet.add(layers.Dense(num_classes, activation='softmax'))  # Adjust num_classes based on your dataset

# Compile the model
lenet.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
lenet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 508, 508, 6)       456
#
#  max_pooling2d (MaxPooling2D  (None, 254, 254, 6)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 250, 250, 16)      2416
#
#  max_pooling2d_1 (MaxPooling  (None, 125, 125, 16)     0
#  2D)
#
#  flatten (Flatten)           (None, 250000)            0
#
#  dense (Dense)               (None, 120)               30000120
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 4)                 340
#
# =================================================================
# Total params: 30,013,496
# Trainable params: 30,013,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_generator.class_indices
# Out:
# {'History of MI': 0,
#  'Myocardial Infarction': 1,
#  'Normal': 2,
#  'abnormal heartbeat': 3}

# %%
# Train the model
epochs = 50

history = lenet.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator
)

# Save the trained model
lenet_path = f'{model_save_dir}/lenet5_ecg_model.hd5'
lenet.save(lenet_path)

# lenet_loaded_model = tf.keras.saving.load_model(f'{model_save_dir}/lenet5_ecg_model.keras')
# Out:
# Epoch 1/50
# 24/24 [==============================] - 255s 10s/step - loss: 7.9038 - accuracy: 0.2322 - val_loss: 1.3818 - val_accuracy: 0.2623
# Epoch 2/50
# 24/24 [==============================] - 201s 9s/step - loss: 1.3769 - accuracy: 0.2899 - val_loss: 1.3649 - val_accuracy: 0.3005
# Epoch 3/50
# 24/24 [==============================] - 107s 4s/step - loss: 1.3543 - accuracy: 0.3664 - val_loss: 1.3169 - val_accuracy: 0.4153
# Epoch 4/50
# 24/24 [==============================] - 109s 5s/step - loss: 1.3162 - accuracy: 0.3879 - val_loss: 1.2913 - val_accuracy: 0.3333
# Epoch 5/50
# 24/24 [==============================] - 109s 4s/step - loss: 1.2944 - accuracy: 0.4081 - val_loss: 1.2202 - val_accuracy: 0.4317
# Epoch 6/50
# 24/24 [==============================] - 108s 4s/step - loss: 1.1988 - accuracy: 0.4779 - val_loss: 1.1250 - val_accuracy: 0.5519
# Epoch 7/50
# 24/24 [==============================] - 108s 4s/step - loss: 1.0669 - accuracy: 0.5799 - val_loss: 1.0126 - val_accuracy: 0.5956
# Epoch 8/50
# 24/24 [==============================] - 109s 5s/step - loss: 1.0419 - accuracy: 0.5611 - val_loss: 1.0282 - val_accuracy: 0.6284
# Epoch 9/50
# 24/24 [==============================] - 111s 5s/step - loss: 0.9234 - accuracy: 0.6081 - val_loss: 0.8189 - val_accuracy: 0.6721
# Epoch 10/50
# 24/24 [==============================] - 110s 5s/step - loss: 0.8609 - accuracy: 0.6805 - val_loss: 0.8355 - val_accuracy: 0.6721
# Epoch 11/50
# 24/24 [==============================] - 106s 4s/step - loss: 0.7867 - accuracy: 0.7020 - val_loss: 0.7525 - val_accuracy: 0.6995
# Epoch 12/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.7923 - accuracy: 0.6926 - val_loss: 0.8382 - val_accuracy: 0.7049
# Epoch 13/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.8243 - accuracy: 0.6738 - val_loss: 0.7658 - val_accuracy: 0.6995
# Epoch 14/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.7328 - accuracy: 0.7289 - val_loss: 0.7024 - val_accuracy: 0.7322
# Epoch 15/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.7316 - accuracy: 0.7101 - val_loss: 0.6948 - val_accuracy: 0.7049
# Epoch 16/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.7353 - accuracy: 0.7060 - val_loss: 0.7051 - val_accuracy: 0.7158
# Epoch 17/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.6888 - accuracy: 0.7503 - val_loss: 0.6969 - val_accuracy: 0.7322
# Epoch 18/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.6573 - accuracy: 0.7570 - val_loss: 0.5932 - val_accuracy: 0.7541
# Epoch 19/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.6527 - accuracy: 0.7477 - val_loss: 0.6123 - val_accuracy: 0.7978
# Epoch 20/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.5602 - accuracy: 0.7893 - val_loss: 0.4937 - val_accuracy: 0.8415
# Epoch 21/50
# 24/24 [==============================] - 110s 5s/step - loss: 0.5452 - accuracy: 0.8000 - val_loss: 0.5310 - val_accuracy: 0.8251
# Epoch 22/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.5150 - accuracy: 0.8107 - val_loss: 0.5960 - val_accuracy: 0.8033
# Epoch 23/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.4776 - accuracy: 0.8228 - val_loss: 0.5136 - val_accuracy: 0.8415
# Epoch 24/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.4852 - accuracy: 0.8121 - val_loss: 0.3830 - val_accuracy: 0.8798
# Epoch 25/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.4249 - accuracy: 0.8510 - val_loss: 0.4018 - val_accuracy: 0.8415
# Epoch 26/50
# 24/24 [==============================] - 107s 5s/step - loss: 0.4032 - accuracy: 0.8470 - val_loss: 0.3729 - val_accuracy: 0.8525
# Epoch 27/50
# 24/24 [==============================] - 117s 5s/step - loss: 0.4311 - accuracy: 0.8403 - val_loss: 0.3212 - val_accuracy: 0.9126
# Epoch 28/50
# 24/24 [==============================] - 119s 5s/step - loss: 0.3633 - accuracy: 0.8738 - val_loss: 0.4619 - val_accuracy: 0.8689
# Epoch 29/50
# 24/24 [==============================] - 104s 4s/step - loss: 0.3888 - accuracy: 0.8711 - val_loss: 0.3097 - val_accuracy: 0.8907
# Epoch 30/50
# 24/24 [==============================] - 105s 4s/step - loss: 0.3465 - accuracy: 0.8752 - val_loss: 0.3314 - val_accuracy: 0.8798
# Epoch 31/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.2824 - accuracy: 0.8886 - val_loss: 0.2644 - val_accuracy: 0.8962
# Epoch 32/50
# 24/24 [==============================] - 108s 4s/step - loss: 0.2642 - accuracy: 0.9007 - val_loss: 0.2700 - val_accuracy: 0.8852
# Epoch 33/50
# 24/24 [==============================] - 108s 4s/step - loss: 0.2666 - accuracy: 0.9047 - val_loss: 0.2745 - val_accuracy: 0.8962
# Epoch 34/50
# 24/24 [==============================] - 108s 4s/step - loss: 0.3181 - accuracy: 0.8913 - val_loss: 0.2513 - val_accuracy: 0.9126
# Epoch 35/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.2691 - accuracy: 0.8980 - val_loss: 0.2861 - val_accuracy: 0.9126
# Epoch 36/50
# 24/24 [==============================] - 106s 5s/step - loss: 0.2540 - accuracy: 0.9060 - val_loss: 0.2756 - val_accuracy: 0.9071
# Epoch 37/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.2705 - accuracy: 0.9074 - val_loss: 0.2343 - val_accuracy: 0.9126
# Epoch 38/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.2233 - accuracy: 0.9114 - val_loss: 0.3345 - val_accuracy: 0.8907
# Epoch 39/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.2116 - accuracy: 0.9275 - val_loss: 0.2533 - val_accuracy: 0.9126
# Epoch 40/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.1936 - accuracy: 0.9302 - val_loss: 0.1951 - val_accuracy: 0.9399
# Epoch 41/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.2180 - accuracy: 0.9128 - val_loss: 0.2607 - val_accuracy: 0.9180
# Epoch 42/50
# 24/24 [==============================] - 106s 4s/step - loss: 0.2171 - accuracy: 0.9195 - val_loss: 0.3047 - val_accuracy: 0.8907
# Epoch 43/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.2250 - accuracy: 0.9208 - val_loss: 0.2177 - val_accuracy: 0.9290
# Epoch 44/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.1697 - accuracy: 0.9490 - val_loss: 0.2691 - val_accuracy: 0.9126
# Epoch 45/50
# 24/24 [==============================] - 108s 4s/step - loss: 0.1548 - accuracy: 0.9463 - val_loss: 0.2240 - val_accuracy: 0.9290
# Epoch 46/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.1744 - accuracy: 0.9329 - val_loss: 0.2365 - val_accuracy: 0.9235
# Epoch 47/50
# 24/24 [==============================] - 107s 5s/step - loss: 0.2076 - accuracy: 0.9262 - val_loss: 0.3932 - val_accuracy: 0.8689
# Epoch 48/50
# 24/24 [==============================] - 106s 4s/step - loss: 0.1936 - accuracy: 0.9262 - val_loss: 0.2834 - val_accuracy: 0.8798
# Epoch 49/50
# 24/24 [==============================] - 107s 4s/step - loss: 0.1757 - accuracy: 0.9383 - val_loss: 0.2161 - val_accuracy: 0.9235
# Epoch 50/50
# 24/24 [==============================] - 108s 4s/step - loss: 0.1661 - accuracy: 0.9436 - val_loss: 0.1572 - val_accuracy: 0.9399
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: saved_models/lenet5_ecg_model.hd5\assets
# INFO:tensorflow:Assets written to: saved_models/lenet5_ecg_model.hd5\assets

# %%
plot_hist(lenet)

# %% [markdown]
# # Alex Net

# %%
def alexnet_model(input_shape=(64, 64, 12), num_classes=4):
    model = models.Sequential()

    # Layer 1
    model.add(layers.Conv2D(96, (11, 11), strides=(4, 4), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((3, 3), strides=(2, 2)))

    # Layer 2
    model.add(layers.Conv2D(256, (5, 5), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((3, 3), strides=(2, 2)))

    # Layer 3
    model.add(layers.Conv2D(384, (3, 3), padding='same', activation='relu'))

    # Layer 4
    model.add(layers.Conv2D(384, (3, 3), padding='same', activation='relu'))

    # Layer 5
    model.add(layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Global Average Pooling
    model.add(layers.GlobalAveragePooling2D())

    # Dense layers
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))

    # Output layer
    model.add(layers.Dense(num_classes, activation='softmax'))

    return model

# Create the AlexNet model
alex_net = alexnet_model(input_shape=input_shape, num_classes=num_classes)


# Compile the model with a specified learning rate
learning_rate = 0.001  # Set your desired learning rate
optimizer = Adam(learning_rate=learning_rate)
alex_net.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])


alex_net.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 126, 126, 96)      34944
#
#  max_pooling2d_2 (MaxPoolin  (None, 62, 62, 96)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 62, 62, 256)       614656
#
#  max_pooling2d_3 (MaxPoolin  (None, 30, 30, 256)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 30, 30, 384)       885120
#
#  conv2d_5 (Conv2D)           (None, 30, 30, 384)       1327488
#
#  conv2d_6 (Conv2D)           (None, 30, 30, 256)       884992
#
#  max_pooling2d_4 (MaxPoolin  (None, 15, 15, 256)       0
#  g2D)
#
#  global_average_pooling2d (  (None, 256)               0
#  GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 4096)              1052672
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 4)                 16388
#
# =================================================================
# Total params: 21597572 (82.39 MB)
# Trainable params: 21597572 (82.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
epochs = 10

history = alex_net.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator
)

# Save the trained model
alex_net_path = f'{model_save_dir}/alex_net_ecg_model.hd5'
alex_net.save(alex_net_path)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 87s 4s/step - loss: 1.5234 - accuracy: 0.2792 - val_loss: 1.3717 - val_accuracy: 0.3060
# Epoch 2/10
# 24/24 [==============================] - 80s 3s/step - loss: 1.3772 - accuracy: 0.2966 - val_loss: 1.3748 - val_accuracy: 0.3060
# Epoch 3/10
# 24/24 [==============================] - 84s 4s/step - loss: 1.3768 - accuracy: 0.3047 - val_loss: 1.3713 - val_accuracy: 0.3060
# Epoch 4/10
# 24/24 [==============================] - 78s 3s/step - loss: 1.3738 - accuracy: 0.3060 - val_loss: 1.3720 - val_accuracy: 0.3060
# Epoch 5/10
# 24/24 [==============================] - 81s 3s/step - loss: 1.3743 - accuracy: 0.3060 - val_loss: 1.3714 - val_accuracy: 0.3060
# Epoch 6/10
# 24/24 [==============================] - 77s 3s/step - loss: 1.3743 - accuracy: 0.3060 - val_loss: 1.3719 - val_accuracy: 0.3060
# Epoch 7/10
# 24/24 [==============================] - 82s 3s/step - loss: 1.3752 - accuracy: 0.3060 - val_loss: 1.3713 - val_accuracy: 0.3060
# Epoch 8/10
# 24/24 [==============================] - 82s 3s/step - loss: 1.3715 - accuracy: 0.3074 - val_loss: 1.3715 - val_accuracy: 0.3060
# Epoch 9/10
# 24/24 [==============================] - 84s 3s/step - loss: 1.3744 - accuracy: 0.3060 - val_loss: 1.3715 - val_accuracy: 0.3060
# Epoch 10/10
# 24/24 [==============================] - 77s 3s/step - loss: 1.3723 - accuracy: 0.3060 - val_loss: 1.3715 - val_accuracy: 0.3060

# %%
# Plotting accuracy history
plot_hist(alex_net)

# %% [markdown]
# ## VGG-16

# %%
def vgg16_model(input_shape=(64, 64, 12), num_classes=4):
    model = models.Sequential()

    # Block 1
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=input_shape))
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Block 2
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Block 3
    model.add(layers.Conv2D(96, (3, 3), activation='relu', padding='same'))
    model.add(layers.Conv2D(96, (3, 3), activation='relu', padding='same'))
    model.add(layers.Conv2D(96, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Flatten the output and add Dense layers
    model.add(layers.Flatten())
    model.add(layers.Dense(256, activation='relu'))
    # model.add(layers.Dropout(0.5))
    # model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))

    # Output layer
    model.add(layers.Dense(num_classes, activation='softmax'))

    return model

# Create the VGG16-like model
vgg16_net = vgg16_model(input_shape=input_shape, num_classes=num_classes)

# Compile the model
vgg16_net.compile(optimizer='adam',
                       loss='categorical_crossentropy',
                       metrics=['accuracy'])

# Print a summary of the model architecture
vgg16_net.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 512, 512, 32)      896
#
#  conv2d_8 (Conv2D)           (None, 512, 512, 32)      9248
#
#  max_pooling2d_5 (MaxPoolin  (None, 256, 256, 32)      0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 64)      18496
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 64)      36928
#
#  max_pooling2d_6 (MaxPoolin  (None, 128, 128, 64)      0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 96)      55392
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 96)      83040
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 96)      83040
#
#  max_pooling2d_7 (MaxPoolin  (None, 64, 64, 96)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 393216)            0
#
#  dense_6 (Dense)             (None, 256)               100663552
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 100951620 (385.10 MB)
# Trainable params: 100951620 (385.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
epochs = 10

history = vgg16_net.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator
)

# Save the trained model
vgg16_net_path = f'{model_save_dir}/vgg16_ecg_model.hd5'
vgg16_net.save(vgg16_net_path)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 119s 4s/step - loss: 2.4853 - accuracy: 0.2711 - val_loss: 1.3745 - val_accuracy: 0.3060
# Epoch 2/10
# 24/24 [==============================] - 87s 4s/step - loss: 1.3860 - accuracy: 0.2966 - val_loss: 1.3827 - val_accuracy: 0.3060
# Epoch 3/10
# 24/24 [==============================] - 83s 3s/step - loss: 1.3855 - accuracy: 0.2617 - val_loss: 1.3819 - val_accuracy: 0.3060
# Epoch 4/10
# 24/24 [==============================] - 83s 3s/step - loss: 1.3819 - accuracy: 0.2631 - val_loss: 1.3800 - val_accuracy: 0.3060
# Epoch 5/10
# 24/24 [==============================] - 83s 3s/step - loss: 1.3809 - accuracy: 0.3034 - val_loss: 1.3787 - val_accuracy: 0.3060
# Epoch 6/10
# 24/24 [==============================] - 85s 3s/step - loss: 1.3773 - accuracy: 0.3101 - val_loss: 1.3765 - val_accuracy: 0.3060
# Epoch 7/10
# 24/24 [==============================] - 84s 4s/step - loss: 1.3757 - accuracy: 0.3047 - val_loss: 1.3750 - val_accuracy: 0.3060
# Epoch 8/10
# 24/24 [==============================] - 84s 4s/step - loss: 1.3745 - accuracy: 0.3060 - val_loss: 1.3737 - val_accuracy: 0.3060
# Epoch 9/10
# 24/24 [==============================] - 83s 3s/step - loss: 1.3733 - accuracy: 0.3060 - val_loss: 1.3728 - val_accuracy: 0.3060
# Epoch 10/10
# 24/24 [==============================] - 82s 4s/step - loss: 1.3720 - accuracy: 0.3060 - val_loss: 1.3723 - val_accuracy: 0.3060

# %%
plot_hist(vgg16_net)

# %% [markdown]
# ## GoogleNet

# %%
def inception_module(x, filters):
    # 1x1 Convolution
    conv1x1_1 = layers.Conv2D(filters[0], (1, 1), padding='same', activation='relu')(x)

    # 1x1 Convolution followed by 3x3 Convolution
    conv1x1_2 = layers.Conv2D(filters[1], (1, 1), padding='same', activation='relu')(x)
    conv3x3 = layers.Conv2D(filters[2], (3, 3), padding='same', activation='relu')(conv1x1_2)

    # 1x1 Convolution followed by 5x5 Convolution
    conv1x1_3 = layers.Conv2D(filters[3], (1, 1), padding='same', activation='relu')(x)
    conv5x5 = layers.Conv2D(filters[4], (5, 5), padding='same', activation='relu')(conv1x1_3)

    # 3x3 MaxPooling followed by 1x1 Convolution
    maxpool = layers.MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    conv1x1_4 = layers.Conv2D(filters[5], (1, 1), padding='same', activation='relu')(maxpool)

    # Concatenate the output of all branches
    inception = layers.concatenate([conv1x1_1, conv3x3, conv5x5, conv1x1_4], axis=-1)

    return inception

def googlenet_model(input_shape=(64, 64, 12), num_classes=4):
    input_layer = layers.Input(shape=input_shape)

    # Initial Convolutional Layer
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(input_layer)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception Module 1
    x = inception_module(x, filters=[8, 32, 32, 8, 8, 8])

    # Inception Module 2
    x = inception_module(x, filters=[8, 32, 32, 8, 8, 8])

    # Flatten and Dense Layers
    x = layers.Flatten()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)

    # Output layer
    output_layer = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=input_layer, outputs=output_layer)

    return model

# Create the GoogLeNet-like model
googlenet = googlenet_model(input_shape=input_shape, num_classes=num_classes)

# Compile the model
googlenet.compile(optimizer='adam',
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])

# Print a summary of the model architecture
googlenet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  conv2d_14 (Conv2D)          (None, 256, 256, 64)         9472      ['input_1[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 128, 128, 64)         0         ['conv2d_14[0][0]']
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 32)         2080      ['max_pooling2d_8[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 128, 128, 8)          520       ['max_pooling2d_8[0][0]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 128, 128, 64)         0         ['max_pooling2d_8[0][0]']
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 8)          520       ['max_pooling2d_8[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 128, 128, 32)         9248      ['conv2d_16[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 128, 128, 8)          1608      ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 128, 128, 8)          520       ['max_pooling2d_9[0][0]']
#
#  concatenate (Concatenate)   (None, 128, 128, 56)         0         ['conv2d_15[0][0]',
#                                                                      'conv2d_17[0][0]',
#                                                                      'conv2d_19[0][0]',
#                                                                      'conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 128, 128, 32)         1824      ['concatenate[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 128, 128, 8)          456       ['concatenate[0][0]']
#
#  max_pooling2d_10 (MaxPooli  (None, 128, 128, 56)         0         ['concatenate[0][0]']
#  ng2D)
#
#  conv2d_21 (Conv2D)          (None, 128, 128, 8)          456       ['concatenate[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 128, 128, 32)         9248      ['conv2d_22[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 128, 128, 8)          1608      ['conv2d_24[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 128, 128, 8)          456       ['max_pooling2d_10[0][0]']
#
#  concatenate_1 (Concatenate  (None, 128, 128, 56)         0         ['conv2d_21[0][0]',
#  )                                                                   'conv2d_23[0][0]',
#                                                                      'conv2d_25[0][0]',
#                                                                      'conv2d_26[0][0]']
#
#  flatten_2 (Flatten)         (None, 917504)               0         ['concatenate_1[0][0]']
#
#  dense_8 (Dense)             (None, 128)                  1174406   ['flatten_2[0][0]']
#                                                           40
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['dense_8[0][0]']
#
#  dense_9 (Dense)             (None, 4)                    516       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 117479172 (448.15 MB)
# Trainable params: 117479172 (448.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Train the model
epochs = 10

history = googlenet.fit(
                          train_generator,
                          epochs=epochs,
                          validation_data=validation_generator
                      )

# Save the trained model
googlenet_path = f'{model_save_dir}/googlenet_ecg_model.hd5'
googlenet.save(googlenet_path)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 91s 3s/step - loss: 7.8344 - accuracy: 0.2497 - val_loss: 1.3803 - val_accuracy: 0.3060
# Epoch 2/10
# 24/24 [==============================] - 79s 3s/step - loss: 1.3869 - accuracy: 0.2604 - val_loss: 1.3855 - val_accuracy: 0.3060
# Epoch 3/10
# 24/24 [==============================] - 84s 4s/step - loss: 1.3850 - accuracy: 0.3047 - val_loss: 1.3844 - val_accuracy: 0.3060
# Epoch 4/10
# 24/24 [==============================] - 80s 3s/step - loss: 1.3871 - accuracy: 0.3060 - val_loss: 1.3840 - val_accuracy: 0.3060
# Epoch 5/10
# 24/24 [==============================] - 85s 4s/step - loss: 1.3824 - accuracy: 0.2966 - val_loss: 1.3719 - val_accuracy: 0.3060
# Epoch 6/10
# 24/24 [==============================] - 80s 3s/step - loss: 1.3773 - accuracy: 0.3060 - val_loss: 1.3752 - val_accuracy: 0.3115
# Epoch 7/10
# 24/24 [==============================] - 83s 4s/step - loss: 1.3745 - accuracy: 0.3128 - val_loss: 1.3676 - val_accuracy: 0.3224
# Epoch 8/10
# 24/24 [==============================] - 84s 4s/step - loss: 1.3787 - accuracy: 0.3020 - val_loss: 1.3741 - val_accuracy: 0.3060
# Epoch 9/10
# 24/24 [==============================] - 78s 3s/step - loss: 1.3775 - accuracy: 0.3034 - val_loss: 1.3728 - val_accuracy: 0.3060
# Epoch 10/10
# 24/24 [==============================] - 83s 3s/step - loss: 1.3734 - accuracy: 0.3060 - val_loss: 1.3720 - val_accuracy: 0.3060

# %%
plot_hist(googlenet)

# %% [markdown]
# ## ResNet50

# %%
from tensorflow.keras.applications import ResNet50

# Load the pre-trained ResNet50 model with weights from ImageNet
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

# Freeze the convolutional layers
for layer in base_model.layers:
    layer.trainable = False

# Create a custom head for your specific task
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output_layer = layers.Dense(num_classes, activation='softmax')(x)

# Combine the base model with the custom head
resnet = models.Model(inputs=base_model.input, outputs=output_layer)

# Compile the model
resnet.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

resnet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 518, 518, 3)          0         ['input_2[0][0]']
#
#  conv1_conv (Conv2D)         (None, 256, 256, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 256, 256, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 256, 256, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 258, 258, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 128, 128, 64)         0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 128, 128, 64)         4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 128, 128, 64)         36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 128, 128, 256)        16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 128, 128, 256)        16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 128, 128, 256)        0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 128, 128, 256)        0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 128, 128, 64)         16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 128, 128, 64)         36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 128, 128, 256)        16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 128, 128, 256)        0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 128, 128, 256)        0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 128, 128, 64)         16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 128, 128, 64)         36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 128, 128, 256)        16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 128, 128, 256)        0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 128, 128, 256)        0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 64, 64, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 64, 64, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 64, 64, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 64, 64, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 64, 64, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 64, 64, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 64, 64, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 64, 64, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 64, 64, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 64, 64, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 64, 64, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 64, 64, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 64, 64, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 32, 32, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 32, 32, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 16, 16, 512)          524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 16, 16, 512)          2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 16, 16, 2048)         2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 16, 16, 2048)         1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 16, 16, 2048)         0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 16, 16, 2048)         0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 16, 16, 512)          1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 16, 16, 512)          2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 16, 16, 2048)         1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 16, 16, 2048)         0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 16, 16, 2048)         0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 16, 16, 512)          1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 16, 16, 512)          2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 16, 16, 2048)         1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 16, 16, 2048)         0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 16, 16, 2048)         0         ['conv5_block3_add[0][0]']
#  on)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['conv5_block3_out[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_10 (Dense)            (None, 1024)                 2098176   ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dropout_4 (Dropout)         (None, 1024)                 0         ['dense_10[0][0]']
#
#  dense_11 (Dense)            (None, 4)                    4100      ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 25689988 (98.00 MB)
# Trainable params: 2102276 (8.02 MB)
# Non-trainable params: 23587712 (89.98 MB)
# __________________________________________________________________________________________________

# %%
# Train the model
epochs = 10
history = resnet.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator
)

# Save the trained model
resnet_path = f'{model_save_dir}/resnet_ecg_model.hd5'

resnet.save(resnet_path)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 104s 4s/step - loss: 2.8910 - accuracy: 0.2738 - val_loss: 1.6440 - val_accuracy: 0.2568
# Epoch 2/10
# 24/24 [==============================] - 84s 4s/step - loss: 1.8365 - accuracy: 0.2832 - val_loss: 1.3919 - val_accuracy: 0.2951
# Epoch 3/10
# 24/24 [==============================] - 82s 3s/step - loss: 1.4180 - accuracy: 0.3450 - val_loss: 1.3250 - val_accuracy: 0.3115
# Epoch 4/10
# 24/24 [==============================] - 84s 3s/step - loss: 1.3408 - accuracy: 0.3745 - val_loss: 1.2702 - val_accuracy: 0.4863
# Epoch 5/10
# 24/24 [==============================] - 88s 4s/step - loss: 1.3189 - accuracy: 0.3597 - val_loss: 1.3031 - val_accuracy: 0.4317
# Epoch 6/10
# 24/24 [==============================] - 85s 4s/step - loss: 1.3453 - accuracy: 0.3812 - val_loss: 1.3019 - val_accuracy: 0.3388
# Epoch 7/10
# 24/24 [==============================] - 82s 3s/step - loss: 1.3147 - accuracy: 0.3893 - val_loss: 1.2807 - val_accuracy: 0.3989
# Epoch 8/10
# 24/24 [==============================] - 83s 3s/step - loss: 1.3210 - accuracy: 0.3638 - val_loss: 1.2420 - val_accuracy: 0.4973
# Epoch 9/10
# 24/24 [==============================] - 85s 4s/step - loss: 1.2779 - accuracy: 0.4470 - val_loss: 1.2317 - val_accuracy: 0.4754
# Epoch 10/10
# 24/24 [==============================] - 82s 3s/step - loss: 1.2839 - accuracy: 0.4067 - val_loss: 1.2156 - val_accuracy: 0.4754

# %%
plot_hist(resnet)

# %% [markdown]
# ## Models performance comparison

# %%
lenet_path = f'{model_save_dir}/lenet5_ecg_model.hd5'
alex_net_path = f'{model_save_dir}/alex_net_ecg_model.hd5'
vgg16_net_path = f'{model_save_dir}/vgg16_ecg_model.hd5'
googlenet_path = f'{model_save_dir}/googlenet_ecg_model.hd5'
resnet_path = f'{model_save_dir}/resnet_ecg_model.hd5'


#Loading Models:
lenet = tf.keras.saving.load_model(lenet_path)
alex_net = tf.keras.saving.load_model(alex_net_path)
vgg16_net = tf.keras.saving.load_model(vgg16_net_path)
googlenet = tf.keras.saving.load_model(googlenet_path)
resnet = tf.keras.saving.load_model(resnet_path)

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#      -------------------------------------- 294.6/294.6 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\python\python310\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pandas>=1.2 in c:\python\python310\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\python\python310\lib\site-packages (from seaborn) (1.22.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in c:\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (9.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.0.7)
# Requirement already satisfied: pytz>=2020.1 in c:\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Function to print evaluation metrics and plot confusion matrix heatmap
def print_evaluation(model, generator, model_name):
    print(f"=================================== Evaluation for {model_name} ===================================")
    y_true = generator.classes
    class_labels = list(generator.class_indices.keys())

    # Get predictions from the model
    y_pred_prob = model.predict(generator)
    y_pred = np.argmax(y_pred_prob, axis=1)


    print("Classification Report:")
    print(classification_report(y_true, y_pred, target_names=class_labels))

    # Create confusion matrix
    conf_matrix = confusion_matrix(y_true, y_pred)

    # Plotting confusion matrix heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_labels, yticklabels=class_labels)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
    print("\n\n")

# Print evaluation for each model

models = {"LeNet": lenet, "Alex Net": alex_net, "VGG-16": vgg16_net, "GoogleNet": googlenet, "ResNet": resnet}

for model_name, model in models.items():
    print_evaluation(model, validation_generator, model_name)
# Out:
# =================================== Evaluation for LeNet ===================================
# 6/6 [==============================] - 14s 2s/step
# Classification Report:
#                        precision    recall  f1-score   support
#
#         History of MI       0.19      0.18      0.18        34
# Myocardial Infarction       0.17      0.17      0.17        47
#                Normal       0.29      0.29      0.29        56
#    abnormal heartbeat       0.22      0.24      0.23        46
#
#              accuracy                           0.22       183
#             macro avg       0.22      0.22      0.22       183
#          weighted avg       0.22      0.22      0.22       183
# =================================== Evaluation for Alex Net ===================================
# 6/6 [==============================] - 17s 2s/step
# Classification Report:
#                        precision    recall  f1-score   support
#
#         History of MI       0.00      0.00      0.00        34
# Myocardial Infarction       0.00      0.00      0.00        47
#                Normal       0.31      1.00      0.47        56
#    abnormal heartbeat       0.00      0.00      0.00        46
#
#              accuracy                           0.31       183
#             macro avg       0.08      0.25      0.12       183
#          weighted avg       0.09      0.31      0.14       183
# c:\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# =================================== Evaluation for VGG-16 ===================================
# 6/6 [==============================] - 36s 4s/step
# Classification Report:
#                        precision    recall  f1-score   support
#
#         History of MI       0.00      0.00      0.00        34
# Myocardial Infarction       0.00      0.00      0.00        47
#                Normal       0.31      1.00      0.47        56
#    abnormal heartbeat       0.00      0.00      0.00        46
#
#              accuracy                           0.31       183
#             macro avg       0.08      0.25      0.12       183
#          weighted avg       0.09      0.31      0.14       183
# c:\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# =================================== Evaluation for GoogleNet ===================================
# 6/6 [==============================] - 15s 2s/step
# Classification Report:
#                        precision    recall  f1-score   support
#
#         History of MI       0.00      0.00      0.00        34
# Myocardial Infarction       0.00      0.00      0.00        47
#                Normal       0.31      1.00      0.47        56
#    abnormal heartbeat       0.00      0.00      0.00        46
#
#              accuracy                           0.31       183
#             macro avg       0.08      0.25      0.12       183
#          weighted avg       0.09      0.31      0.14       183
# c:\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# =================================== Evaluation for ResNet ===================================
# 6/6 [==============================] - 66s 10s/step
# Classification Report:
#                        precision    recall  f1-score   support
#
#         History of MI       0.00      0.00      0.00        34
# Myocardial Infarction       0.50      0.02      0.04        47
#                Normal       0.31      0.73      0.44        56
#    abnormal heartbeat       0.28      0.30      0.29        46
#
#              accuracy                           0.31       183
#             macro avg       0.27      0.26      0.19       183
#          weighted avg       0.29      0.31      0.22       183
# c:\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
